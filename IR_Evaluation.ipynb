# %%
# !git clone https://github.com/lechauanh/Image-Retrieval-Based-on-Resnet
# Out:
# Cloning into 'Image-Retrieval-Based-on-Resnet'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 0), reused 24 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 16.49 KiB | 8.24 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/Image-Retrieval-Based-on-Resnet/requirements.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
# !unzip /content/drive/MyDrive/revisitiop.zip -d /content/Image-Retrieval-Based-on-Resnet
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001989.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001990.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001991.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001992.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001993.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001994.jpg
#   inflating: /content/Image-Retrieval-Based-on-Resnet/revisitiop/data/datasets/rparis6k/jpg/paris_general_001995.jpg
# ...

# %%
# %cd /content/Image-Retrieval-Based-on-Resnet
# Out:
# /content/Image-Retrieval-Based-on-Resnet

# %%
# !pip install yacs -q

# %%
# !python test.py SENET.RESNET_DEPTH 101 TEST.WEIGHTS ./ TEST.DATA_DIR ./revisitiop/data/datasets
# Out:
# 2024-07-01 10:59:57.912276: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 10:59:57.912329: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 10:59:57.913819: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-01 10:59:57.921462: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
